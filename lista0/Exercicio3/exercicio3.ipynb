# %%
3. Neste exercício você irá plotar um gráfico 2D. Este tipo de gráfico é comumente
utilizado para se analisar os dados de entrada e saída de um modelo de aprendizado de
máquina. Crie um vetor coluna, y, com M = 1000 elementos, onde y é dado pela
seguinte equação
y = 1.2 + 2.3*x + 10*w,
onde x é um vetor coluna com M elementos retirados de uma distribuição aleatória
uniforme e w é um vetor coluna com M elementos retirados de uma distribuição
aleatória Gaussiana normal, i.e., com média 0 e variância unitária.
a. Plote um gráfico com os vetores x e y sendo os eixos x e y, respectivamente.
Dica :
● Use o módulo random da biblioteca numpy para gerar números aleatórios
https://docs.scipy.org/doc/numpy-1.14.0/reference/routines.random.html
● Use a biblioteca matplotlib para plotar gráficos
https://matplotlib.org/3.1.3/gallery/lines_bars_and_markers/simple_plot.html

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from random import random as rnd

#Data for plotting
m = 1000 #nº de elementos
x = np.random.uniform(size=m) # vetor coluna com M elementos retirados de uma distribuição aleatória uniforme
w = np.random.normal(0,1,m) # vetor coluna com M elementos retirados de uma distribuição aleatória Gaussiana normal
y = 1.2 + 2.3*x + 10*w

fig, ax = plt.subplots()
ax.plot(x, y, '.')

ax.set(xlabel='input (x)', ylabel='output (y)',
       title='Gráfico 2D input e output')
ax.grid()

fig.savefig("grafico.png")
plt.show()
